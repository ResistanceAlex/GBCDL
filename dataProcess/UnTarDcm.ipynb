# %%
import os
import tarfile

# %%
'''
文件数据结构：
data-----
        |
        -----类别1
        |       |
        |       -----患者1
        |       |       |
        |       |       -----文件1.dcm
        |       |       |
        |       |       -----文件2.dcm
        |       |       。。。
        |       |
        |       -----患者2
        |       |       |
        |       |       -----文件1.dcm
        |       |       |
        |       |       -----文件2.dcm
        |       |       。。。
        |       。。。
        |
        |
        -----类别2
        |       |
        |       -----患者1
        |       |       |
        |       |       -----文件1.dcm
        |       |       |
        |       |       -----文件2.dcm
        |       |       。。。
        |       |
        |       -----患者2
        |       |       |
        |       |       -----文件1.dcm
        |       |       |
        |       |       -----文件2.dcm
        |       |       。。。
        |       。。。
        |
        |
        -----类别3
                |
                -----患者1
                |       |
                |       -----文件1.dcm
                |       |
                |       -----文件2.dcm
                |       。。。
                |
                -----患者2
                |       |
                |       -----文件1.dcm
                |       |
                |       -----文件2.dcm
                |       。。。
                。。。
'''


'''
dcm文件解压函数。

param：
- root_folder: 文件夹根路径

return:
- none

'''
# def extract_tar_files(root_folder):
#     # 遍历父文件夹下的所有子文件夹
#     for folder_name in os.listdir(root_folder):
#         folder_path = os.path.join(root_folder, folder_name)
#         # 检查子文件夹是否为目录
#         if os.path.isdir(folder_path):
#             # 遍历当前子文件夹下的所有子子文件夹
#             for subfolder_name in os.listdir(folder_path):
#                 subfolder_path = os.path.join(folder_path, subfolder_name)
#                 # 检查子子文件夹是否为目录
#                 if os.path.isdir(subfolder_path):
#                     # 遍历当前子子文件夹下的所有文件
#                     for file in os.listdir(subfolder_path):
#                         if file.endswith('.tar'):
#                             tar_path = os.path.join(subfolder_path, file)
#                             # 打开 tar 文件
#                             with tarfile.open(tar_path, 'r') as tar:
#                                 # 逐个提取文件并指定提取的目标路径
#                                 for member in tar.getmembers():
#                                     tar.extract(member, path=subfolder_path)
#                             # 解压完后删除 .tar 文件
#                             os.remove(tar_path)

# # 指定根文件夹路径
# root_folder = "D:/CTData/test"
# # 调用函数解压 tar 文件
# extract_tar_files(root_folder)

# %%
import os
import cv2
import pydicom
from shutil import copyfile
import numpy as np

# %%
'''
归一化函数

param：
- img: 图像路径

return:
- img: 图像路径
'''
def to255(img):
    min_val = img.min()
    max_val = img.max()
    
    # 图像归一化
    img = (img - min_val) / (max_val - min_val + 1e-5)
    img = img * 255
    return img

# %%
'''
窗宽、窗位调整函数

param：
- ds: 原始dcm图像路径

return:
- ct_image: 转化后的图像
'''
def normalize_image(ds):
    info20 = ds.RescaleIntercept
    info21 = int(ds.RescaleSlope)
    info22 = ds.pixel_array
    CT = info21 * info22 + info20
    info18 = ds.WindowCenter
    info19 = ds.WindowWidth
    if(isinstance(info18, pydicom.valuerep.DSfloat)):
        info18 = ds.WindowCenter
        info19 = ds.WindowWidth
    elif(isinstance(info18, pydicom.multival.MultiValue)):
        info18 = ds.WindowCenter[0]
        info19 = ds.WindowWidth[0]
    else:
        pass
    CT_min = info18 - info19/2
    CT_max = info18 + info19/2
    CT = np.clip(CT,CT_min,CT_max)

    # 归一化
    ct_image = to255(CT)
    return ct_image

# %%
'''
dcm转换jpg函数

param：
- input_folder: 原始dcm图像路径
- output_folder: 输出jpg图像路径

return:
- none
'''
def dicom_to_jpg(input_folder, output_folder):
    # 遍历输入文件夹下的所有子文件夹和文件
    for root, dirs, files in os.walk(input_folder):
        # 获取相对于输入文件夹的路径
        relative_path = os.path.relpath(root, input_folder)
        # 构建输出文件夹路径
        output_subfolder = os.path.join(output_folder, relative_path)
        os.makedirs(output_subfolder, exist_ok=True)
        print('正在遍历'+output_subfolder)
        # 遍历当前文件夹下的所有文件
        for file in files:
            if file.endswith('.dcm'):
                try:
                    dicom_path = os.path.join(root, file)
                    output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')

                    # 读取 DICOM 文件
                    dicom_data = pydicom.dcmread(dicom_path)
                    # 归一化图像数组
                    normalized_image = normalize_image(dicom_data)
                    # 使用 OpenCV 将归一化后的图像数组保存为 JPG 文件
                    cv2.imwrite(output_path, normalized_image)
                except Exception as e:
                    print(f"处理文件 {dicom_path} 时出错：{e}")
                    pass
        print('遍历完成'+output_subfolder)

# %%
'''
文件结构复制函数

param：
- input_folder: 原始dcm图像路径
- output_folder: 输出jpg图像路径

return:
- none

'''
def create_folder_structure(input_folder, output_folder):
    # 遍历输入文件夹下的所有子文件夹
    for root, dirs, files in os.walk(input_folder):
        # 获取相对于输入文件夹的路径
        relative_path = os.path.relpath(root, input_folder)
        # 构建输出文件夹路径
        output_subfolder = os.path.join(output_folder, relative_path)
        os.makedirs(output_subfolder, exist_ok=True)

        # 遍历当前文件夹下的所有文件
        for file in files:
            if not file.endswith('.dcm'):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_subfolder, file)
                # 复制非 DICOM 文件到输出文件夹
                copyfile(input_path, output_path)

# %%
# 输入文件夹路径（包含DICOM文件）
input_folder = 'D:/CTData/test_3'
# 输出文件夹路径（保存转换后的JPEG文件）
output_folder = 'D:/CTData/test_4'


# 将DICOM文件转换为JPEG格式并保存至输出文件夹
dicom_to_jpg(input_folder, output_folder)

# 根据原始文件结构创建相同的文件结构并复制非DICOM文件到输出文件夹
create_folder_structure(input_folder, output_folder)

print("转换完成并保存至 " + output_folder)
# Out:
# 正在遍历D:/CTData/test_4\.
# 遍历完成D:/CTData/test_4\.
# 正在遍历D:/CTData/test_4\meCT
# 遍历完成D:/CTData/test_4\meCT
# 正在遍历D:/CTData/test_4\meCT\0001858059
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154739.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154740.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154741.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154742.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154743.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154744.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154755.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154757.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154759.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154760.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154762.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154765.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154766.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154796.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154798.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154801.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154803.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154805.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70154807.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001858059\70156371.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 遍历完成D:/CTData/test_4\meCT\0001858059
# 正在遍历D:/CTData/test_4\meCT\0001892297
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063688.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063690.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063692.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063694.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063696.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063697.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063699.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063701.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063703.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063705.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063707.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063709.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063711.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063713.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063715.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063717.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063719.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063721.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063723.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063725.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063727.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063729.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063731.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063733.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063735.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063736.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063738.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063740.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063742.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063744.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063746.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063748.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063750.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063752.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063754.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063756.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063758.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063760.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063762.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063764.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063766.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063768.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063770.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063772.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063773.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063775.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063777.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063779.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063781.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063783.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063785.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063787.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063789.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063790.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063792.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063794.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063796.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063798.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063799.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063801.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063802.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063804.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063806.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063807.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063809.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063811.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063813.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063815.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063816.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063818.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063820.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063822.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063824.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063826.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063828.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063829.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063831.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063833.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063835.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063836.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063838.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063840.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063842.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063844.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063846.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063848.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063850.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063851.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063853.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063855.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063857.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063859.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063861.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063863.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063865.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063867.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063870.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063872.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063874.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063876.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063878.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063880.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063882.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063884.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063886.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063888.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063890.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063892.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063894.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063896.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063898.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063900.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063902.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063904.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063906.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063908.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063910.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063912.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063913.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063916.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063918.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063921.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063923.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063924.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063926.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063929.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063931.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063933.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063934.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063936.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063938.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063940.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063942.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063946.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063948.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063950.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063952.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063954.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063956.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063957.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063960.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063963.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063964.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063966.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063968.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063970.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063973.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063975.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063977.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063979.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063981.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063983.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063985.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063987.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063989.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063991.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063993.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063996.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063997.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80063999.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064001.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064003.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064005.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064007.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064009.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064011.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064013.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064015.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064018.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064020.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064023.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064024.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064026.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064028.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064030.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064032.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064034.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064036.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064038.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064041.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064043.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064046.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064048.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064050.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064051.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064053.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064055.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064058.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064060.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064061.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064063.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064065.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064068.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064070.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064072.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064073.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064075.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064077.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064079.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064081.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064083.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064085.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064087.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064090.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064092.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064094.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064096.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064098.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064100.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064102.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064104.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064106.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064108.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064110.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064113.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064115.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064117.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064119.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064121.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064123.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064125.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064127.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064129.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064130.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064133.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064135.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064137.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064139.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064141.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064142.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064144.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064146.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064148.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064150.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064152.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064153.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064155.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064157.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064160.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064162.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064164.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064165.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064168.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064169.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064171.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064173.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064175.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064179.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064180.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064182.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064185.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064187.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064189.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064191.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064194.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064196.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064198.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064200.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064202.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064204.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064206.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064208.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064212.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064214.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064216.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064218.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064221.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064223.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064225.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064227.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064229.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064231.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064233.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064236.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064238.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064241.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064243.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80064245.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\meCT\0001892297\80236780.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 遍历完成D:/CTData/test_4\meCT\0001892297
# 正在遍历D:/CTData/test_4\noCT
# 遍历完成D:/CTData/test_4\noCT
# 正在遍历D:/CTData/test_4\noCT\0001573022
# 遍历完成D:/CTData/test_4\noCT\0001573022
# 正在遍历D:/CTData/test_4\noCT\0001607226
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270170.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270173.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270175.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270177.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270198.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270200.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\noCT\0001607226\249270203.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 遍历完成D:/CTData/test_4\noCT\0001607226
# 正在遍历D:/CTData/test_4\noCT\0001644464
# 处理文件 D:/CTData/test_3\noCT\0001644464\253018406.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 遍历完成D:/CTData/test_4\noCT\0001644464
# 正在遍历D:/CTData/test_4\opCT
# 遍历完成D:/CTData/test_4\opCT
# 正在遍历D:/CTData/test_4\opCT\0003058779
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924742.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924746.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924749.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924753.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924757.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924762.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924765.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924769.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924773.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924777.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924781.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924785.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924787.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924790.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924794.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924798.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924802.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924807.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924812.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924816.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924820.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924822.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924825.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924829.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924833.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924837.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924841.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924845.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924849.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924853.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924859.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924862.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924865.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924868.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924872.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924876.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924882.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924884.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924888.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924892.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924897.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924901.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924905.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924909.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924913.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924916.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924920.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924924.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924929.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924931.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924935.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924938.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924942.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924945.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924949.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924952.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924957.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924961.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924966.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924970.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924975.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924980.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924986.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924991.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924995.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421924998.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925002.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925007.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925011.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925015.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925019.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925023.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925027.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925031.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925036.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925040.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925044.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925049.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925053.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925057.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925061.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925065.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925069.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925073.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925077.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925081.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925085.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925089.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925094.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925097.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925103.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925107.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925111.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925115.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925118.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925123.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925128.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925132.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925136.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925139.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925143.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925146.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925150.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925154.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925159.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925166.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925168.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925172.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925176.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925180.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925184.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925188.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925192.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925195.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003058779\421925198.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# ...
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668278.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668284.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668291.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668297.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668302.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668310.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668315.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668320.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668325.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668329.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668335.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668340.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668344.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668348.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668353.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668363.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668379.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668384.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668390.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668395.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668400.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668405.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668413.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668418.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668423.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668428.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668433.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668438.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668444.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668449.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668455.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668460.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668466.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668471.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668477.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668482.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668488.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668494.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668500.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668504.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668508.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668512.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668532.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668539.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668544.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668549.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668554.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668563.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668569.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668574.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668579.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668584.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668589.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668594.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668599.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668604.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668609.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668617.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668622.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668627.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668633.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668638.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668643.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668649.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668654.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668660.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668665.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668670.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668675.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668680.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668685.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668689.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668701.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668704.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668708.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668713.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668719.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668723.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668727.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668731.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668735.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668738.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668743.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668748.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668752.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668756.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668760.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668766.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668770.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668774.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668778.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668782.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668786.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668790.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668794.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668798.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668802.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668808.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668812.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668816.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668819.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668823.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668827.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668831.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668835.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668839.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668843.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668847.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668851.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668855.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668859.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668863.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668867.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668871.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668873.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668880.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668884.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668891.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668897.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668902.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668908.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668914.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668919.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668926.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668931.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668935.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668940.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668945.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668953.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668959.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668964.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668969.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668974.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668979.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694668984.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718702.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718708.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718714.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718720.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718725.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 处理文件 D:/CTData/test_3\opCT\0003370678\694718732.dcm 时出错：'FileDataset' object has no attribute 'RescaleIntercept'
# 遍历完成D:/CTData/test_4\opCT\0003370678
# 转换完成并保存至 D:/CTData/test_4
